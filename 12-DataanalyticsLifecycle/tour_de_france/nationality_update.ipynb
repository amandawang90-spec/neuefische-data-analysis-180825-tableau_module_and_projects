# %%
import pandas as pd

df=pd.read_excel('tour_de_france.xlsx')

# %%
df
# Out:
#      Winner's avg speed  Total distance (km)  Number of stages  Finishers  \
# 0                25.680               2428.0                 6         21
# 1                25.270               2420.0                 6         27
# 2                27.110               2994.0                11         24
# 3                24.460               4545.0                13         14
# 4                28.470               4488.0                14         33
# ..                  ...                  ...               ...        ...
# 98               39.880               3496.9                20        153
# 99               40.540               3403.5                21        169
# 100              40.690               3659.0                21        164
# 101              39.640               3360.3                21        160
# 102              39.616               3534.0                21        174
#
#      Entrants               Winner Winner's Nationality   Winner's Team  \
# ...

# %%
df["Winner's Nationality"] = df["Winner's Nationality"].replace("Result voided", "United States")

# %%
df.to_excel('tour_de_france.xlsx', index=False)

# %%
df["Winner"]
# Out:
# 0            Maurice Garin
# 1             Henri Cornet
# 2        Louis Trousselier
# 3             René Pottier
# 4      Lucien Petit-Breton
#               ...
# 98         Bradley Wiggins
# 99            Chris Froome
# 100        Vincenzo Nibali
# 101          Chris Froome
# 102          Chris Froome
# Name: Winner, Length: 103, dtype: object

# %%
df[df["Winner's Nationality"] == "Result voided"]
# Out:
# Empty DataFrame
# Columns: [Winner's avg speed, Total distance (km), Number of stages, Finishers, Entrants, Winner, Winner's Nationality, Winner's Team, Start/Finish Cities, Start/Finish City Coordinates, Start/Finish Dates]
# Index: []

# %%
df[df["Winner's Nationality"] == "United States"]
# Out:
#      Winner's avg speed  Total distance (km)  Number of stages  Finishers  \
# 0                25.680               2428.0                 6         21
# 1                25.270               2420.0                 6         27
# 2                27.110               2994.0                11         24
# 3                24.460               4545.0                13         14
# 4                28.470               4488.0                14         33
# ..                  ...                  ...               ...        ...
# 98               39.880               3496.9                20        153
# 99               40.540               3403.5                21        169
# 100              40.690               3659.0                21        164
# 101              39.640               3360.3                21        160
# 102              39.616               3534.0                21        174
#
#      Entrants               Winner Winner's Nationality   Winner's Team  \
# ...
